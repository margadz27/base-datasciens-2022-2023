# %%
import matplotlib.pyplot as plt

# %%
burger =	6
pizza =	3
dimsum =	4
ekkado =	4
milkshake =	2
eskrim =	5
jml1 = burger + pizza + dimsum + ekkado + milkshake + eskrim
jml = (burger * 24000) + (pizza * 52000) + (dimsum * 30000) + (ekkado * 7500) + (milkshake * 10000) + (eskrim * 15000)
print("jumlah banyak belanjaan adalah : " + str(jml1))
print("maka jumlah semua belanjaan adalah : " + str(jml))

print("")
print("soal no 2")
jml1 = burger + pizza + dimsum + ekkado + milkshake + eskrim
print("jumlah banyak belanjaan adalah : " + str(jml1))
p_burger = burger /24
print("jumlah persentase adalah : " + str(p_burger))
p_pizza = pizza /24
print("jumlah persentase adalah : " + str(p_pizza))
p_dimsum = dimsum /24
print("jumlah persentase adalah : " + str(p_dimsum))
p_ekkado = ekkado /24
print("jumlah persentase adalah : " + str(p_ekkado))
p_milkshake = milkshake /24
print("jumlah persentase adalah : " + str(p_milkshake))
p_eskrim = eskrim /24
print("jumlah persentase adalah : " + str(p_eskrim))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("data persantase pesanan makanan")
mkn = ['burger' , 'pizza ','dimsum' , 'ekkado' , 'milkshake' , 'eskrim']
persentase   = [0.25, 0.125,0.16666666666666666,0.16666666666666666,0.08333333333333333,0.20833333333333334]
ax.pie(persentase,labels=mkn,autopct='1%.2f%%')
plt.show()

print("")
print("soal 3") 
print("pemesanan ahmad")
burger = 4 
pizza = 2 
uang = 200000
jml_a =( 0.70 * ((burger * 24000) + (pizza * 52000))) + (7.5 * 2000) - 5000
print("maka jumlah belanjaan ahmad adalah :  " + str(jml_a))
hasil = uang - jml_a
print("maka total kembalian ahmad adalah : " + str(hasil))

print("pemesanan beni")
dimsum = 3 
eskrim = 1
milkshake = 2
uang_b = 150000
jml_b = (0.70 * ((dimsum * 30000) + (eskrim * 15000) + (milkshake * 10000))) + (4 * 1800) - 5000
print("maka jumlah belanjaan beni adalah :  " + str(jml_b))
hasil_b = uang_b - jml_b
print("maka total kembalian beni adalah : " + str(hasil_b))
print("")

print("pemesanan citra")
eskrim = 3 
uang_c = 60000
jml_c = (eskrim * 15000)  + (8 * 2000) -5000
print("maka jumlah belanjaan citra adalah : " + str(jml_c))
hasil_c = uang_c - jml_c
print("maka total kembalian citra adalah : " + str(hasil_c))
print("")

print("pemesanan dadang")
burger = 2
dimsum = 1
uang_d = 100000 
jml_d = (0.80 *((burger * 24000) + (dimsum * 30000))) + (5 * 1800) - 5000
print("maka jumlah belanjaan dadang adalah :  " + str(jml_d))
hasil_d = uang_d - jml_d
print("maka total kembalian dadang adalah : " + str(hasil_d))
print("")

print("pemesanan epen")
ekkado = 4
eskrim = 1
pizza  = 1
uang_e = 100000
jml_e = (0.70*((ekkado * 7500 )+(eskrim * 15000) +(pizza * 52000)))  + (12 * 2200) - 5000
print("amak jjumlah belanjaan epen adalah : " + str(jml_e))
hasil_e = uang_e - jml_e
print("maka total kembalian epen adalah : " + str(hasil_e))
print("")

print("soal 4")
burger = 4 
pizza = 2 
pot_a =( 0.30 * ((burger * 24000) + (pizza * 52000))) + 5000
print("maka jumlah potongan ahmad adalah :  " + str(pot_a))
print("")
dimsum = 3 
eskrim = 1
milkshake = 2
pot_b = (0.30 * ((dimsum * 30000) + (eskrim * 15000) + (milkshake * 10000))) +  5000
print("maka jumlah potongan beni adalah :  " + str(pot_b))
print("")
pot_c = 5000
print("maka jumlah potongan citra adalah : " + str(pot_c))
print("")
burger = 2
dimsum = 1 
pot_d = (0.20 *((burger * 24000) + (dimsum * 30000))) +  5000
print("maka jumlah potongan dadang adalah :  " + str(pot_d))
print("")
ekkado = 4
eskrim = 1
pizza  = 1
pot_e = (0.30*((ekkado * 7500 )+(eskrim * 15000) +(pizza * 52000)))  +  5000
print("maka jumlah potongan epen adalah : " + str(pot_e))
print("")
hasil = pot_a + pot_b + pot_c +pot_d+pot_e
print("maka jumlah potongan semua pembeli adalah :" + str(hasil))
print("soal 5")
jarak_a = 7.5
ongkos_a = 2000
jarak_b = 4
ongkos_b = 1800
jarak_c = 8
ongkos_c = 2000
jarak_d = 5
ongkos_d = 1800
jarak_e = 12
ongkos_e = 2200
jml = (jarak_a * ongkos_a) + (jarak_b * ongkos_b) + (jarak_c * ongkos_c) + (jarak_d * ongkos_d) + (jarak_e * ongkos_e)    
print("maka jumlah semua ongkir semua pembeli adalah :  "+str ( jml))
